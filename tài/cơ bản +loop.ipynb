# %%
##1
a= open('đề bài 1 CN.fasta').read()
b= a.split('\n')
d = a.count('G')
e= a.count('C')
gc_total=d+e
seq=''
header=''
for each in b:
    if each =='>':
        header = each
    elif seq=='':
        seq = each
    elif seq !='':
        seq = seq + each
        k=len(seq)
        gc_rate = gc_total/ k
print(k)
print(gc_rate)
ba=''
for data in list(seq):
    if data =='A':
        data='T'
        ba=ba + data
    elif data =='T':
        data='A'
        ba=ba + data
    elif data =='G':
        data='C'
        ba=ba + data
    elif data =='C':
        data='G'
        ba=ba + data
print(ba)
# Out:
# 1230302
# 0.40575565999242463
# ...

# %%
##2
a= open('rosalind_gc (1).txt','r')
b=a.readlines()
a.close()
c={}
header=''
d=''
for each in b : 
    if each[0]=='>':
        d= each[:1].rstrip()
        header= each
        c[d]=''
    else: 
        c[d]+=each.rstrip()
for e,f in c.items(): 
    c[e] = (float(f.count('G')+f.count('C'))/len(f))*100
    e= max(list(c.items()))
for g,h in c.items():
    c[g]=(float(len(f)))
    g=max(list(c.items()))
print(g)
print(e)
total=0
seq=''
for line in b : 
    if line[0] =='>': 
        header = line
        total +=1
        seq=''
    if seq =='':
        seq=line
    elif seq!='':
        seq=line+seq
print(total)
# Out:
# ('>', 957.0)
# ('>', 49.42528735632184)
# 6
