# %%
n= 33
k= 2
c,d=0,1
if n > 1:
    for K in range(1,n):
        c,d=d,(k*c)+d
print(d)
# Out:
# 2863311531

# %%
T='...'
K='...'
a=len(K)
count = 0
for k in range(a):
    if T[k] != K[k]: 
        count += 1
print(count)
# Out:
# 451
